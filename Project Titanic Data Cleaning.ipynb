# %%
import pandas as pd
titanic=pd.read_csv(r"C:\Users\sagni\OneDrive\Desktop\titanic_train.csv")
titanic
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
#need to look at column headers ->
print(titanic.columns)
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
print(titanic.dtypes)
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
#so got a little bit idea of what columns are and what all they store

# %%
#firstly we will drop clearly not useful to predict if person survived/not walle columns/features
del titanic['PassengerId']
del titanic['Name']
del titanic['SibSp']
del titanic['Parch']
del titanic['Ticket']
del titanic['Fare']
del titanic['Cabin']

# %%
titanic.head(50)
# Out:
#     Survived  Pclass     Sex   Age Embarked
# 0          0       3    male  22.0        S
# 1          1       1  female  38.0        C
# 2          1       3  female  26.0        S
# 3          1       1  female  35.0        S
# 4          0       3    male  35.0        S
# 5          0       3    male   NaN        Q
# 6          0       1    male  54.0        S
# 7          0       3    male   2.0        S
# 8          1       3  female  27.0        S
# 9          1       2  female  14.0        C
# 10         1       3  female   4.0        S
# 11         1       1  female  58.0        S
# 12         0       3    male  20.0        S
# 13         0       3    male  39.0        S
# 14         0       3  female  14.0        S
# 15         1       2  female  55.0        S
# 16         0       3    male   2.0        Q
# 17         1       2    male   NaN        S
# 18         0       3  female  31.0        S
# 19         1       3  female   NaN        C
# ...

# %%
def return_percentage_survived_with_given_Pclass(p_class):
    a=titanic[titanic.Pclass==p_class]
    b=a[titanic.Survived==1]
    return (len(b)/len(a))*100

# %%
print("Pclass = 1 : ",return_percentage_survived_with_given_Pclass(1))
print("Pclass = 2 : ",return_percentage_survived_with_given_Pclass(2))
print("Pclass = 3 : ",return_percentage_survived_with_given_Pclass(3))
# Out:
# Pclass = 1 :  62.96296296296296
# Pclass = 2 :  47.28260869565217
# Pclass = 3 :  24.236252545824847
# C:\Users\sagni\AppData\Local\Temp\ipykernel_17096\218740650.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   b=a[titanic.Survived==1]

# %%
#so seems like Pclass=3 has lesser survival rates than Pclass=2 and 1 so important factor hai can't drop
def return_percentage_survived_with_given_gender(gender):
    a=titanic[titanic.Sex==gender]
    b=a[titanic.Survived==1]
    return (len(b)/len(a))*100

# %%
print("Gender = Male : ",return_percentage_survived_with_given_gender('male'))
print("Gender = Female : ",return_percentage_survived_with_given_gender('female'))
# Out:
# Gender = Male :  18.890814558058924
# Gender = Female :  74.20382165605095
# C:\Users\sagni\AppData\Local\Temp\ipykernel_17096\2845455064.py:4: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   b=a[titanic.Survived==1]

# %%
def return_percentage_survived_with_given_embarked(embarked):
    a=titanic[titanic.Embarked==embarked]
    b=a[titanic.Survived==1]
    return (len(b)/len(a))*100

# %%
print("Embarked = S : ",return_percentage_survived_with_given_embarked('S'))
print("Embarked = C : ",return_percentage_survived_with_given_embarked('C'))
print("Embarked = Q : ",return_percentage_survived_with_given_embarked('Q'))
# Out:
# Embarked = S :  33.69565217391305
# Embarked = C :  55.35714285714286
# Embarked = Q :  38.961038961038966
# C:\Users\sagni\AppData\Local\Temp\ipykernel_17096\4090737610.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   b=a[titanic.Survived==1]

# %%
#so all the three factors were important
#now input columns sex and embarked have string values so change them
def change_gender(gender):
    if(gender=='male'):
        return 1
    else:
        return 0

# %%
def change_embarked(embarked):
    if(embarked=='S'):
        return 0
    elif(embarked=='T'):
        return 1
    else:
        return 2

# %%
titanic['Gender']=titanic.Sex.apply(change_gender)
titanic['Embarked_from']=titanic.Embarked.apply(change_embarked)
del titanic['Sex']
del titanic['Embarked']
titanic.head(50)
# Out:
#     Survived  Pclass   Age  Gender  Embarked_from
# 0          0       3  22.0       1              0
# 1          1       1  38.0       0              2
# 2          1       3  26.0       0              0
# 3          1       1  35.0       0              0
# 4          0       3  35.0       1              0
# 5          0       3   NaN       1              2
# 6          0       1  54.0       1              0
# 7          0       3   2.0       1              0
# 8          1       3  27.0       0              0
# 9          1       2  14.0       0              2
# 10         1       3   4.0       0              0
# 11         1       1  58.0       0              0
# 12         0       3  20.0       1              0
# 13         0       3  39.0       1              0
# 14         0       3  14.0       0              0
# 15         1       2  55.0       0              0
# 16         0       3   2.0       1              2
# 17         1       2   NaN       1              0
# ...

# %%
import numpy as np
meanS= titanic[titanic.Survived==1].Age.mean()
meanS
# Out:
# 28.343689655172415

# %%
titanic["age"]=np.where(pd.isnull(titanic.Age) & titanic["Survived"]==1  ,meanS, titanic["Age"])
titanic.head(50)
# Out:
#     Survived  Pclass   Age  Gender  Embarked_from       age
# 0          0       3  22.0       1              0  22.00000
# 1          1       1  38.0       0              2  38.00000
# 2          1       3  26.0       0              0  26.00000
# 3          1       1  35.0       0              0  35.00000
# 4          0       3  35.0       1              0  35.00000
# 5          0       3   NaN       1              2       NaN
# 6          0       1  54.0       1              0  54.00000
# 7          0       3   2.0       1              0   2.00000
# 8          1       3  27.0       0              0  27.00000
# 9          1       2  14.0       0              2  14.00000
# 10         1       3   4.0       0              0   4.00000
# 11         1       1  58.0       0              0  58.00000
# 12         0       3  20.0       1              0  20.00000
# 13         0       3  39.0       1              0  39.00000
# 14         0       3  14.0       0              0  14.00000
# ...

# %%
meanUS=titanic[titanic.Survived==0].Age.mean()
meanUS
# Out:
# 30.62617924528302

# %%
#so age contains nan on places  where survived 0 fill that only
titanic.age.fillna(meanNS,inplace=True)
titanic.head(50)
# Out:
#     Survived  Pclass   Age  Gender  Embarked_from        age
# 0          0       3  22.0       1              0  22.000000
# 1          1       1  38.0       0              2  38.000000
# 2          1       3  26.0       0              0  26.000000
# 3          1       1  35.0       0              0  35.000000
# 4          0       3  35.0       1              0  35.000000
# 5          0       3   NaN       1              2  30.626179
# 6          0       1  54.0       1              0  54.000000
# 7          0       3   2.0       1              0   2.000000
# 8          1       3  27.0       0              0  27.000000
# 9          1       2  14.0       0              2  14.000000
# 10         1       3   4.0       0              0   4.000000
# 11         1       1  58.0       0              0  58.000000
# 12         0       3  20.0       1              0  20.000000
# 13         0       3  39.0       1              0  39.000000
# ...

# %%
del titanic['Age']
titanic.head(50)
# Out:
#     Survived  Pclass  Gender  Embarked_from        age
# 0          0       3       1              0  22.000000
# 1          1       1       0              2  38.000000
# 2          1       3       0              0  26.000000
# 3          1       1       0              0  35.000000
# 4          0       3       1              0  35.000000
# 5          0       3       1              2  30.626179
# 6          0       1       1              0  54.000000
# 7          0       3       1              0   2.000000
# 8          1       3       0              0  27.000000
# 9          1       2       0              2  14.000000
# 10         1       3       0              0   4.000000
# 11         1       1       0              0  58.000000
# 12         0       3       1              0  20.000000
# 13         0       3       1              0  39.000000
# 14         0       3       0              0  14.000000
# 15         1       2       0              0  55.000000
# ...
